# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %matplotlib widget

# %%
def open_pkl(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)


plt.close
plt.figure()
plt.axis('equal')
# plt.ylim(0, 1)
filenames = [
    'data/motion_primitives_prius/straight.pkl',
    'data/motion_primitives_prius/left1.pkl',
    'data/motion_primitives_prius/left2.pkl'
]

for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    if filename == filenames[0]:
        plt.scatter(points[:, 0], points[:, 1], color='b', label='MP from pybullet')
    else:
        plt.scatter(points[:, 0], points[:, 1], color='b')
    # plt.plot(-points[:, 1], points[:, 0])

filenames = [
    'data/motion_primitives_bicycle_model/straight.pkl',
    'data/motion_primitives_bicycle_model/left1.pkl',
    'data/motion_primitives_bicycle_model/left2.pkl'
]

for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    if filename == filenames[0]:
        plt.scatter(points[:, 0], points[:, 1], color='r', label='MP from our Bicycle model')
    else:
        plt.scatter(points[:, 0], points[:, 1], color='r')
    # plt.plot(-points[:, 1], points[:, 0])

filenames = [
    'data/motion_primitives_bicycle_model_real_size/straight.pkl',
    'data/motion_primitives_bicycle_model_real_size/left1.pkl',
    'data/motion_primitives_bicycle_model_real_size/left2.pkl',
    'data/motion_primitives_bicycle_model_real_size/left3.pkl'
]

for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    if filename == filenames[0]:
        plt.scatter(points[:, 0], points[:, 1], color='g', label='MP from our Bicycle model')
    else:
        plt.scatter(points[:, 0], points[:, 1], color='g')
    # plt.plot(-points[:, 1], points[:, 0])

plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def open_pkl(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)


plt.close
plt.figure()
plt.axis('equal')
# plt.ylim(0, 1)
filenames = [
    'data/motion_primitives_prius/straight.pkl',
    'data/motion_primitives_prius/left1.pkl',
    'data/motion_primitives_prius/left2.pkl'
]
print("First 3 values for the orientation to check signs:")
for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    print(f"Pybullet {filename}: \t{points[:3, 2]}")
    if filename == filenames[0]:
        plt.plot(points[:, 0], points[:, 1], color='b', label='MP from pybullet')
    else:
        plt.plot(points[:, 0], points[:, 1], color='b')
    # plt.plot(-points[:, 1], points[:, 0])

filenames = [
    'data/motion_primitives_bicycle_model/straight.pkl',
    'data/motion_primitives_bicycle_model/left1.pkl',
    'data/motion_primitives_bicycle_model/left2.pkl'
]

for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    print(f"Bicycle {filename}: \t{points[:3, 2]}")
    if filename == filenames[0]:
        plt.plot(points[:, 0], points[:, 1], color='r', label='MP from our Bicycle model')
    else:
        plt.plot(points[:, 0], points[:, 1], color='r')
    # plt.plot(-points[:, 1], points[:, 0])

plt.legend()
plt.show()
# Out:
# First 3 values for the orientation to check signs:
# Pybullet data/motion_primitives_prius/straight.pkl: 	[0.00000000e+00 1.69162265e-07 1.59966702e-07]
# Pybullet data/motion_primitives_prius/left1.pkl: 	[0.         0.00288585 0.00751021]
# Pybullet data/motion_primitives_prius/left2.pkl: 	[0.         0.00914542 0.01880294]
# Bicycle data/motion_primitives_bicycle_model/straight.pkl: 	[0. 0. 0.]
# Bicycle data/motion_primitives_bicycle_model/left1.pkl: 	[0.         0.00485302 0.00969977]
# Bicycle data/motion_primitives_bicycle_model/left2.pkl: 	[0.         0.00980474 0.01955811]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def open_pkl(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)


plt.close
plt.figure()
plt.axis('equal')
# plt.ylim(0, 1)
filenames = [
    'data/motion_primitives_bicycle_model/straight.pkl',
    'data/motion_primitives_bicycle_model/left1.pkl',
    'data/motion_primitives_bicycle_model/left2.pkl'
]

for filename in filenames:
    points = open_pkl(filename).points
    points = np.array(points)
    plt.plot(points[:, 0], points[:, 1], color='b')
    # plt.plot(-points[:, 1], points[:, 0])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
